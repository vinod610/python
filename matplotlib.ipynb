# %%
import matplotlib.pyplot as plt
plt.plot([4,8,9],[0,0,0],'ro')
plt.ylabel('indeces')
plt.xlabel('numbers')
plt.title('first plot')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
t=np.arange(0,5,0.2)
line =plt.plot(t,t**2,t**2.5,t**3)
plt.setp(line[0],'color','g','linewidth','8','label','t^2')
plt.setp(line[1],'color','r','linewidth','10','label','t^2.5,3')
#plt.plot(t,t**2.5,'ys',label='^2.5')
#plt.plot(t,t**3,'b^',label='^3')
plt.legend()
plt.grid()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import numpy as np
import matplotlib.pyplot as plt
a=np.loadtxt('dob.txt')
year,vinod,dob=a.T
year
vinod
dob
plt.plot(year,vinod,label='year vs vinod',linewidth=5.0)
#plt.plot(year,dob,'g^',label='year vs dob')
#plt.plot(vinod,dob,'b--',label='vinod vs dob')
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
def f(t):
    return np.exp(-t)* np.sin(np.pi*t)
t1=np.arange(0,5,0.2)
t2=np.arange(0,5,0.02)
t3=np.arange(0,5,0.5)
t4=np.arange(0,5,1)
#plt.plot(t1,f(t1),t2,f(t2),t3,f(t3),t4,f(t4))
plt.figure(1)
plt.subplot(2,2,1)
plt.grid()
plt.plot(t1,f(t1),'rs')
plt.subplot(2,2,2)
plt.plot(t2,f(t2),'bxd')
plt.grid()
plt.subplot(2,2,3)
plt.plot(t3,f(t3),'y^')
plt.grid()
plt.subplot(2,2,4)
plt.plot(t4,f(t4),'g--')
plt.figure(1)
plt.subplot(2,2,2)
#plt.plot(t3,f(t3),t2,f(t2),'gs')
#plt.plot(line[0],'color','y')
#plt.plot(line[1],'color','r')
plt.title('sine graph')
plt.figure(1)
plt.subplot(2,2,1)
plt.title('sin graph')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-e178df77c621> in <module>
#      13 plt.plot(t1,f(t1),'rs')
#      14 plt.subplot(2,2,2)
# ---> 15 plt.plot(t2,f(t2),'bz')
#      16 plt.grid()
#      17 plt.subplot(2,2,3)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
# ...
