# %% [markdown]
# import numpy as np
# import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
a= stats.norm.rvs(size=1000)
b=stats.norm.rvs(size=10000)
sns.kdeplot(a,bw=0.5)
plt.show()
stats.kstest(a,'norm')
# Out:
# KstestResult(statistic=0.02377549489491898, pvalue=0.6240582269045543)

# %%
y=stats.uniform.rvs(size=100)
y1=np.random.uniform(0,1,100000)
sns.kdeplot(y1,bw=0.1)
plt.show()
print(stats.kstest(y,'norm'))
print(stats.kstest(y1,'norm'))
# Out:
# KstestResult(statistic=0.5040052137960281, pvalue=4.8389409676522766e-24)
# KstestResult(statistic=0.5000089556192353, pvalue=0.0)

# %%
stats.ks_2samp(a,y1)
# Out:
# Ks_2sampResult(statistic=0.51258, pvalue=2.2335743452934038e-226)
